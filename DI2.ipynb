# %%
import numpy as np
import robosuite as suite

# pid.py
class PDController:
    def __init__(self, kp, kd, target):
        """
        Initialize a PD controller.

        Args:
            kp (float): Proportional gain.
            kd (float): Derivative gain.
            target (tuple or array): Target position.
        """
        self.kp = kp
        self.kd = kd
        # May need some other terms here
        self.target = target

    def reset(self, target=None):
        """
        Reset the target position.

        Args:
            target (tuple or array, optional): New target position.
        """
        pass
    
    def update(self, current_pos):
        """
        Compute the control signal.

        Args:
            current_pos (array-like): Current position.

        Returns:
            np.ndarray: Control output vector.
        """
        pass

# policies.py    
class LiftPolicy(object):
    """
    A simple Pd-controller policy for a robotic arm to move above an object in two phases:
    1. Move towards top of the cube
    2. Close gripper and lift up
    We need a PD controller to drive the robot's end-effector!
    """
    def __init__(self, obs):
        """
        Initialize the LiftPolicy with the first observation from the environment.
        Args:
            obs (dict): Initial observation from the environment. Must include:
                - 'cube_pos': The position of the cube to be touched.
        """
        self.cube_pos = obs["cube_pos"]
        # Hint: There are multiple steps/waypoints in this policy
        # You may want to use a phase variable to track which step you're on
        

    def get_action(self, obs):
        """
        Compute the next action for the robot based on current observation.

        Args:
            obs (dict): Current observation. Must include:
                - 'robot0_eef_pos': Current end-effector position.
                - 'cube_pos': Current position of the cube.

        Returns:
            np.ndarray: 7D action array for robosuite OSC:
                - action[-1]: Gripper command (1 to close, -1 to open)
        """
        # How many dimensions are these?
        eef_pos = obs["robot0_eef_pos"]
        current_cube_pos = obs["cube_pos"]

        # Use controller method to update control signal.

        # Q: for students: What is the action space of the robot?

        # Q: for students: Why do we only set the first 3 values?
        # What do the first 3 values represent??

        return action
        
                
# test.py
# Create environment instance
env = suite.make(
    env_name="Lift",
    robots="Panda",
    has_renderer=True,
    has_offscreen_renderer=False,
    use_camera_obs=False,
)

# Reset the environment
for _ in range(5):
    obs = env.reset()
    policy = LiftPolicy(obs)
    
    while True:
        action = policy.get_action(obs)
        obs, reward, done, info = env.step(action)  # take action in the environment
        
        env.render()  # render on display
        if reward == 1.0 or done:
            print("Finished!")
            break
